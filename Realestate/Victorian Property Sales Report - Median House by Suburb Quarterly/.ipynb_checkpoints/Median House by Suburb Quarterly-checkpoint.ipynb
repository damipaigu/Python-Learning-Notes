# %%
import pandas as pd

# %%
data = pd.read_excel('house-Mar2018-final.xls', header=1, index_cols=1, usecols='A:G'+',I:J', skiprows=[1,2,3],
                    skipfooter=1, names=['Suburb', '1stQ17', '2ndQ17', '3rdQ17', '4thQ17', '1stQ18', 'Sales No. 18',
                                        '% 1stQ17 to 1stQ18', '% 4thQ17 to 1stQ18'])

# %%
data
# Out:
#                       Suburb   1stQ17   2ndQ17   3rdQ17   4thQ17   1stQ18  \
# 0                 ABERFELDIE  1375000  1372500  1536000  1625000  1600000
# 1                    AINTREE   499000   513500   580000   590800   614000
# 2               AIREYS INLET   802500   735000   685000   785000   780000
# 3               AIRPORT WEST   771500   862000   860000   842000   870000
# 4                  ALBANVALE   465000   525000   561000   546000   547000
# 5                ALBERT PARK  1929000  2130000  2420000  2085000  2120000
# 6                     ALBION   685000   716500   642500   769000   702500
# 7                  ALEXANDRA   335000   217500   375000   275000   367000
# 8                  ALFREDTON   410000   417500   414000   415000   420000
# 9                 ALPHINGTON  1583500  1810000  1730000  1870000  1720000
# 10                    ALTONA   853000   977500   927800  1010000   970000
# 11               ALTONA EAST   810000   885000   832500   950000   907500
# ...
